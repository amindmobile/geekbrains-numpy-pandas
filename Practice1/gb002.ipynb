# %% [markdown]
# <h1>Визуализация данных в Matplotlib</h1>
# <b>Задание 1</b>

# %%
from matplotlib import pyplot as plt
import numpy as np

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'svg'

# %%
x = [1,2,3,4,5,6,7]
y = [3.5,3.8,4.2,4.5,5,5.5,7]

# %%
plt.plot(x, y)
plt.show()

# %%
plt.scatter(x, y)
plt.show()

# %% [markdown]
# <b>Задание 2</b>

# %%
t = np.linspace(0, 10, num=51)
f = np.cos(t)

# %%
plt.xlim(0.5, 9.5)
plt.ylim(-2.5, 2.5)
plt.plot(t, f, color = 'green')
plt.title('График f(t)')
plt.xlabel('Значения t')
plt.ylabel('Значения f')
plt.show()

# %% [markdown]
# <b>Задание 3</b>

# %%
x = np.linspace(-3, 3, num=51)
y1 = x**2
y2 = (2*x) + 0.5
y3 = (-3*x) - 1.5
y4 = np.sin(x)

# %%
fig, ax = plt.subplots(nrows=2, ncols=2)
fig.set_size_inches(8, 6)
plt.subplots_adjust(wspace=0.3, hspace=0.3)
ax1, ax2, ax3, ax4 = ax.flatten()
ax1.set_title('График y1')
ax1.plot(x, y1)
ax1.set_xlim([-5, 5])
ax2.set_title('График y2')
ax2.plot(x, y2)
ax3.set_title('График y3')
ax3.plot(x, y3)
ax4.set_title('График y4')
ax4.plot(x, y4)

# %% [markdown]
# <b>Задание 4</b>

# %%
import pandas as pd

# %%
plt.style.use('fivethirtyeight')
df = pd.read_csv('creditcard.csv')

# %%
df

# %%
df1 = df['Class'].value_counts()
df1

# %% [markdown]
# <i>Сделал, но нифига не понял зачем сказали сделать вот эти гистограммы и как их читать.</i>

# %%
df1.plot.hist()
plt.show()

# %%
df1.plot(kind='barh')
plt.show()

# %%
df1.plot.hist(logx=True)
plt.show()

# %%
df1.plot(kind='barh', logx=True)
plt.show()

# %% [markdown]
# <i>Гистограмму ниже делать было сложнее, но она выглядет подробнее. Все еще не понятно как её читать. Как подобрать density пока не вкурил. Зачем x-оси давать название Class? Зачем в задании "подберите значение аргумента density, если здесь это вроде буль: или false или true? </i>

# %%
class0 = df.loc[df['Class'] == 0, ['V1']]
class1 = df.loc[df['Class'] == 1, ['V1']]
plt.hist(class0['V1'], bins=20, density = True, alpha=0.5, label='Class 0', color='grey')
plt.hist(class1['V1'], bins=20, density=True, alpha=0.5, label='Class 1', color='red')
plt.xlabel('Class')
plt.legend()
plt.show()
